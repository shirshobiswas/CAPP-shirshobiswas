# %%
from __future__ import division
import pandas as pd
import numpy as np
from sklearn import preprocessing, cross_validation, svm, metrics, tree, \
decomposition, svm
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, \
GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression, Perceptron, SGDClassifier, \
OrthogonalMatchingPursuit, RandomizedLogisticRegression
from sklearn.neighbors.nearest_centroid import NearestCentroid
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cross_validation import train_test_split
from sklearn.grid_search import ParameterGrid
from sklearn.metrics import *
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, \
f1_score, roc_auc_score, precision_recall_curve
import random
import pylab as pl
import matplotlib.pyplot as plt
from scipy import optimize
import csv
import time


def define_clfs_params():


    clfs = {'RF': RandomForestClassifier(n_estimators=50, n_jobs=-1),
        
        'LR': LogisticRegression(penalty='l1', C=1e5),
        'GB': GradientBoostingClassifier(learning_rate=0.05, subsample=0.5, \
            max_depth=6, n_estimators=10),
        'NB': GaussianNB(),
        'DT': DecisionTreeClassifier(),
        'SVM': svm.LinearSVC(random_state=0, dual = False),
        'KNN': KNeighborsClassifier(n_neighbors=5) 
            }

    grid = { 
    'RF':{'n_estimators': [1,10,100], 'max_depth': [1,5,10,20], 'max_features': ['sqrt','log2'], 'min_samples_split': [2,5,10]},
    'LR': { 'penalty': ['l1','l2'], 'C': [0.00001,0.0001,0.001,0.01,0.1]},
    'GB': {'n_estimators': [1,10,100], 'learning_rate' : [0.01,0.05,0.1], 'subsample' : [0.1,0.5], 'max_depth': [1,3,5,10]},
    'NB' : {},
    'DT': {'criterion': ['gini', 'entropy'], 'max_depth': [1,5,10,20,50], 'max_features': ['sqrt','log2'],'min_samples_split': [2,5,10]},
    'SVM' :{'C' :[0.001,0.01,0.1,1],'penalty':['l1','l2']},
    'KNN' :{'n_neighbors': [1,5,10,25],'weights': ['uniform','distance'], 'algorithm': ['ball_tree']}
           }

    return clfs, grid

def clf_loop(models_to_run,clfs,grid,X,y):

    best_model = ''
    best_params = ''
    best_auc = -1


    with open ('output/results.csv', 'w') as csvfile:
        w = csv.writer(csvfile, delimiter=',')
        w.writerow(['Classification_Model', 'Parameters', 'auc', 'time'])

        X_train, X_test, y_train, y_test = train_test_split(X, y, \
            test_size=0.2, random_state=0)
        for index,clf in enumerate([clfs[x] for x in models_to_run]):
            
            current_model = models_to_run[index]
            current_params = grid[current_model]

            start_time = time.time()
            print(models_to_run[index])
            parameter_values = grid[models_to_run[index]]
            for p in ParameterGrid(parameter_values):
                try:
                    clf.set_params(**p)
                    print(clf)

                    if hasattr(clf,'predict_proba'):
                       y_pred_probs = clf.fit(X_train, y_train).predict_proba(X_test)[:,1]
                    else: 
                       y_pred_probs = clf.fit(X_train, y_train).decision_function(X_test)

                    threshold = np.sort(y_pred_probs)[::-1][int(.05*len(y_pred_probs))]
                    #print (threshold)
                    end_time=time.time()
                    print(models_to_run[index], "used:",end_time-start_time)
                    #print (precision_at_k(y_test,y_pred_probs,.05))
                    #plot_precision_recall_n(y_test,y_pred_probs,clf)
                    current_auc = roc_auc_score(y_test, y_pred_probs)

                    if current_auc > best_auc:
                        best_model = current_model
                        best_params = current_params
                        best_pred_y = y_pred_probs
                    print("AUC:",current_auc)
                    print()
                except IndexError as e:
                    print ('Error:',e)
                    continue
                w.writerow([current_model, clf, current_auc, end_time-start_time])
    plot_precision_recall_n(y_test, y_pred_probs, best_model)
    print("~"*101)
    print(best_model,best_params, best_auc)
    return best_model, best_params, best_auc, best_pred_y

def evaluate(y_true, y_predict):
    evaluation = dict()

    try:
        evaluation['accuracy'] = accuracy_score(y_true, y_predict)
        evaluation['precision'] = precision_score(y_true, y_predict)
        evaluation['recall'] = recall_score(y_true, y_predict)
        evaluation['f1'] = f1_score(y_true, y_predict)
        evaluation['area_under_curve'] = roc_auc_score(y_true, y_predict),
        evaluation['precision_at_k'] = precision_at_k(y_true,y_predict, 0.05)

    except:
        print("No metrics.")

    return evaluation

def plot_precision_recall_n(y_true, y_prob, model_name):
    from sklearn.metrics import precision_recall_curve
    y_score = y_prob
    precision_curve, recall_curve, \
    pr_thresholds = precision_recall_curve(y_true, y_score)
    precision_curve = precision_curve[:-1]
    recall_curve = recall_curve[:-1]
    pct_above_per_thresh = []
    number_scored = len(y_score)
    for value in pr_thresholds:
        num_above_thresh = len(y_score[y_score>=value])
        pct_above_thresh = num_above_thresh / float(number_scored)
        pct_above_per_thresh.append(pct_above_thresh)
    pct_above_per_thresh = np.array(pct_above_per_thresh)
    plt.clf()
    fig, ax1 = plt.subplots()
    ax1.plot(pct_above_per_thresh, precision_curve, 'b')
    ax1.set_xlabel('percent of population')
    ax1.set_ylabel('precision', color='b')
    ax2 = ax1.twinx()
    ax2.plot(pct_above_per_thresh, recall_curve, 'r')
    ax2.set_ylabel('recall', color='r')
    
    name = model_name
    plt.title(name)
    #plt.savefig(name)
    plt.show()

def precision_at_k(y_true, y_scores, k):
    threshold = np.sort(y_scores)[::-1][int(k*len(y_scores))]
    y_pred = np.asarray([1 if i >= threshold else 0 for i in y_scores])
    return metrics.precision_score(y_true, y_pred)

def get_y_x(df):
    y = df['SeriousDlqin2yrs']
    df.drop('SeriousDlqin2yrs', axis = 1, inplace = True)
    return y, df

def main(filename): 
    clfs,grid = define_clfs_params()
    models_to_run=['KNN', 'RF', 'LR', 'GB','DT', 'SVM']

    #get X and y
    df = pd.read_csv(filename, index_col = 0)
    y, X = get_y_x(df)

    best_model, best_params, best_auc, best_pred_y = clf_loop(models_to_run,clfs,grid,X,y)

# %%
main('training_imputed.csv')
# Out:
# KNN
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=1, p=2, weights='uniform')
# ('KNN', 'used:', 8.52924108505249)
# ('AUC:', 0.50502013869947215)
# ()
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=1, p=2, weights='distance')
# ('KNN', 'used:', 16.919592142105103)
# ('AUC:', 0.50502013869947215)
# ()
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=5, p=2, weights='uniform')
# ('KNN', 'used:', 24.736189126968384)
# ('AUC:', 0.50637511445755501)
# ()
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=5, p=2, weights='distance')
# ('KNN', 'used:', 33.77424097061157)
# ('AUC:', 0.50686261229332485)
# ()
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=10, p=2, weights='uniform')
# ('KNN', 'used:', 41.460692167282104)
# ('AUC:', 0.52012256568199078)
# ()
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=10, p=2, weights='distance')
# ('KNN', 'used:', 49.16830110549927)
# ('AUC:', 0.51902147607950688)
# ()
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=25, p=2, weights='uniform')
# ('KNN', 'used:', 58.097570180892944)
# ('AUC:', 0.52939492543886579)
# ()
# KNeighborsClassifier(algorithm='ball_tree', leaf_size=30, metric='minkowski',
#            metric_params=None, n_neighbors=25, p=2, weights='distance')
# ('KNN', 'used:', 66.88381600379944)
# ('AUC:', 0.52816146522198248)
# ()
# RF
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 0.1261751651763916)
# ('AUC:', 0.60050225548286684)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 0.671518087387085)
# ('AUC:', 0.79714778924791341)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 3.0818819999694824)
# ('AUC:', 0.82889077206900708)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 3.2082509994506836)
# ('AUC:', 0.66742102422132743)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 3.7538580894470215)
# ('AUC:', 0.81689532965903111)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 6.8737170696258545)
# ('AUC:', 0.82955951461084976)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 7.017046213150024)
# ('AUC:', 0.61959702956874663)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 7.550089120864868)
# ('AUC:', 0.82163869025418046)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 10.17090916633606)
# ('AUC:', 0.82802385440853687)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 10.298843145370483)
# ('AUC:', 0.65429713567358549)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 10.727950096130371)
# ('AUC:', 0.80254399495512219)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 13.743935108184814)
# ('AUC:', 0.82783087922013499)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 13.875798225402832)
# ('AUC:', 0.66742102422132743)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 14.308574199676514)
# ('AUC:', 0.81144089173655964)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 17.740334033966064)
# ('AUC:', 0.82868551489052544)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 17.87085199356079)
# ('AUC:', 0.60050225548286684)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 18.30258321762085)
# ('AUC:', 0.7957673215759935)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=1, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 20.904420137405396)
# ('AUC:', 0.83078462342464221)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 21.142426013946533)
# ('AUC:', 0.79814951116016208)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 21.985913038253784)
# ('AUC:', 0.84580800971690129)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 29.094463109970093)
# ('AUC:', 0.85048774557655316)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 29.326717138290405)
# ('AUC:', 0.76266343647701329)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 30.167639017105103)
# ('AUC:', 0.84785625698062173)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 37.42177200317383)
# ('AUC:', 0.84973498126650737)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 37.65071511268616)
# ('AUC:', 0.80741806288732587)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 38.59768104553223)
# ('AUC:', 0.84634524829938218)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 45.94077920913696)
# ('AUC:', 0.85020162685682377)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 46.1668701171875)
# ('AUC:', 0.78573429256463723)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 47.103687047958374)
# ('AUC:', 0.84820227994705033)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 54.13959503173828)
# ('AUC:', 0.85012822380135522)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 54.382721185684204)
# ('AUC:', 0.81007342389020576)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 55.430352210998535)
# ('AUC:', 0.84732110187186815)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 62.76752305030823)
# ('AUC:', 0.85024770839337549)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 63.001742124557495)
# ('AUC:', 0.817862823074335)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 63.93695402145386)
# ('AUC:', 0.84898261964466037)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=5, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 71.64620304107666)
# ('AUC:', 0.84985931562510231)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 72.12413620948792)
# ('AUC:', 0.78885921427023331)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 73.78230118751526)
# ('AUC:', 0.85278991401223792)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 89.90877413749695)
# ('AUC:', 0.85486351312433495)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 90.35754108428955)
# ('AUC:', 0.81079636301122615)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 92.21787619590759)
# ('AUC:', 0.85081387924757046)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 109.7972822189331)
# ('AUC:', 0.85462653987310877)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 110.23971009254456)
# ('AUC:', 0.80889706661080862)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 112.43679904937744)
# ('AUC:', 0.85229751388534569)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 132.9092321395874)
# ('AUC:', 0.85528929461650871)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 133.1414279937744)
# ('AUC:', 0.80580001793188061)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 134.7030861377716)
# ('AUC:', 0.85286048949621973)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 147.78669118881226)
# ('AUC:', 0.85484255582978619)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 148.1275451183319)
# ('AUC:', 0.81258339694493775)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 149.57710099220276)
# ('AUC:', 0.85173323391486944)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 163.26307320594788)
# ('AUC:', 0.85529093163157988)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 163.59542417526245)
# ('AUC:', 0.80068523875146969)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 164.9304871559143)
# ('AUC:', 0.85156501529663642)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=10, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 180.21241903305054)
# ('AUC:', 0.85473666634153966)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 180.75735211372375)
# ('AUC:', 0.61065820069002907)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 183.311350107193)
# ('AUC:', 0.8203078407716935)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 206.89085817337036)
# ('AUC:', 0.84620016674442922)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 207.2459421157837)
# ('AUC:', 0.65243499163660368)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 209.6924819946289)
# ('AUC:', 0.82251494853005769)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 231.54208302497864)
# ('AUC:', 0.8455901116305965)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 232.0847680568695)
# ('AUC:', 0.66960244747584607)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 234.1293442249298)
# ('AUC:', 0.83139384689980245)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='sqrt', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 252.81594610214233)
# ('AUC:', 0.84780810947852547)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 253.25106120109558)
# ('AUC:', 0.57224628109131515)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 255.4119110107422)
# ('AUC:', 0.8189780855506178)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 279.8553349971771)
# ('AUC:', 0.84630957537737461)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 280.30087518692017)
# ('AUC:', 0.63283738254701372)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 282.95903515815735)
# ('AUC:', 0.82200350825460911)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=5,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 305.8718521595001)
# ('AUC:', 0.84775568122578848)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=1, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 306.4187161922455)
# ('AUC:', 0.65846460837320775)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 308.665048122406)
# ('AUC:', 0.83233006194692638)
# ()
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='log2', max_leaf_nodes=None,
#             min_samples_leaf=1, min_samples_split=10,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)
# ('RF', 'used:', 330.46429109573364)
# ('AUC:', 0.84919851304406002)
# ()
# LR
# LogisticRegression(C=1e-05, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)
# ('LR', 'used:', 0.49723005294799805)
# ('AUC:', 0.60215157880649206)
# ()
# LogisticRegression(C=1e-05, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)
# ('LR', 'used:', 2.168670892715454)
# ('AUC:', 0.65129720488343124)
# ()
# LogisticRegression(C=0.0001, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', penalty='l1', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0)
# ('LR', 'used:', 2.609994888305664)
# ('AUC:', 0.6471458922363309)
# ()
# LogisticRegression(C=0.0001, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', penalty='l2', random_state=None,
#           solver='liblinear', tol=0.0001, verbose=0)
# ('LR', 'used:', 4.272853851318359)
# ('AUC:', 0.65171976487001027)
# ()
# LogisticRegression(C=0.001, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)
# ('LR', 'used:', 5.638879060745239)
# ('AUC:', 0.67029036147761434)
# ()
# LogisticRegression(C=0.001, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)
# ('LR', 'used:', 7.338356971740723)
# ('AUC:', 0.65175927208400297)
# ()
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)
# ('LR', 'used:', 10.650500059127808)
# ('AUC:', 0.69413184022151631)
# ()
# LogisticRegression(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)
# ('LR', 'used:', 12.313809871673584)
# ('AUC:', 0.65176392926056936)
# ()
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l1', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)
# ('LR', 'used:', 17.681539058685303)
# ('AUC:', 0.69328658893698902)
# ()
# LogisticRegression(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr',
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0)
# ('LR', 'used:', 19.4479238986969)
# ('AUC:', 0.65176414811285155)
# ()
# GB
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=1, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 0.23436498641967773)
# ('AUC:', 0.65429713567358549)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=1, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 0.4917008876800537)
# ('AUC:', 0.65429713567358549)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=1, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 1.235511064529419)
# ('AUC:', 0.65429713567358549)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=1, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 2.4499518871307373)
# ('AUC:', 0.65429713567358549)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=1, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 8.071233987808228)
# ('AUC:', 0.82532065229675566)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=1, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 18.22768807411194)
# ('AUC:', 0.82257293563076406)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=3, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 18.49354100227356)
# ('AUC:', 0.76079222320145501)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=3, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 18.930387020111084)
# ('AUC:', 0.78928589743380995)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=3, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 20.09671688079834)
# ('AUC:', 0.83262784111625443)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=3, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 22.659563064575195)
# ('AUC:', 0.82289646058257671)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=3, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 33.383322954177856)
# ('AUC:', 0.8423321102292064)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=3, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 56.03982996940613)
# ('AUC:', 0.83472793886268715)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=5, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 56.38697791099548)
# ('AUC:', 0.81141763211600171)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=5, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 56.962790966033936)
# ('AUC:', 0.83227463979496807)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=5, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 59.06840205192566)
# ('AUC:', 0.84423721934624074)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=5, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 63.31137800216675)
# ('AUC:', 0.84334004754627112)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=5, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 82.76389598846436)
# ('AUC:', 0.85002446155729228)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=5, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 124.36102390289307)
# ('AUC:', 0.84900578297021445)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=10, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 125.26934885978699)
# ('AUC:', 0.68320662048813485)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=10, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 127.05452489852905)
# ('AUC:', 0.79714930370570658)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=10, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 138.39543986320496)
# ('AUC:', 0.84318763006281694)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=10, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 160.1568820476532)
# ('AUC:', 0.84925797958619442)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=10, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 269.31034803390503)
# ('AUC:', 0.85093174433270191)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.01, loss='deviance',
#               max_depth=10, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 506.6519410610199)
# ('AUC:', 0.85256482881698381)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.05, loss='deviance',
#               max_depth=1, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 506.91186594963074)
# ('AUC:', 0.65429713567358549)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.05, loss='deviance',
#               max_depth=1, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=1,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 507.1870539188385)
# ('AUC:', 0.65429713567358549)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.05, loss='deviance',
#               max_depth=1, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 507.9557099342346)
# ('AUC:', 0.78340990624525797)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.05, loss='deviance',
#               max_depth=1, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=10,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 509.10557985305786)
# ('AUC:', 0.79267886066062121)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.05, loss='deviance',
#               max_depth=1, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               random_state=None, subsample=0.1, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 515.2242698669434)
# ('AUC:', 0.84364559159457364)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.05, loss='deviance',
#               max_depth=1, max_features=None, max_leaf_nodes=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               random_state=None, subsample=0.5, verbose=0,
#               warm_start=False)
# ('GB', 'used:', 526.6684908866882)
# ('AUC:', 0.84439974780513494)
# ()
# GradientBoostingClassifier(init=None, learning_rate=0.05, loss='deviance',
# ...
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 5.12011194229126)
# ('AUC:', 0.60946475542443335)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 5.775022983551025)
# ('AUC:', 0.64378890832472235)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 6.388640880584717)
# ('AUC:', 0.66582486449410783)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 7.029932975769043)
# ('AUC:', 0.60318026331991459)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 7.638933897018433)
# ('AUC:', 0.63007061697837452)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 8.293299913406372)
# ('AUC:', 0.65738635819490021)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=50,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 8.97902798652649)
# ('AUC:', 0.60760210365015677)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=50,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 9.547086000442505)
# ('AUC:', 0.62800219153422998)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=50,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 10.21801495552063)
# ('AUC:', 0.67237603248160049)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=50,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 10.871878862380981)
# ('AUC:', 0.60611484481858724)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=50,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 11.538233041763306)
# ('AUC:', 0.63504535696041564)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=50,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 12.18442702293396)
# ('AUC:', 0.66802560802810396)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 12.258295059204102)
# ('AUC:', 0.66742102422132743)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 12.333086967468262)
# ('AUC:', 0.61959702956874663)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 12.404651880264282)
# ('AUC:', 0.65429713567358549)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 12.442806005477905)
# ('AUC:', 0.61959702956874663)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 12.529419898986816)
# ('AUC:', 0.66742102422132743)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 12.582728862762451)
# ('AUC:', 0.65429713567358549)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 12.870858907699585)
# ('AUC:', 0.80249233706241863)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 13.208523035049438)
# ('AUC:', 0.82522227381883617)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 13.567426919937134)
# ('AUC:', 0.81505181432831497)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 14.03745698928833)
# ('AUC:', 0.82466770213560081)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 14.288355827331543)
# ('AUC:', 0.80801405893054667)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=5,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 14.719523906707764)
# ('AUC:', 0.82603198349272522)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 15.580659866333008)
# ('AUC:', 0.80510547708300595)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 16.227840900421143)
# ('AUC:', 0.81718656952216551)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 16.92453384399414)
# ('AUC:', 0.8138881767435624)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 17.70117688179016)
# ('AUC:', 0.8147415255625331)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 18.418463945388794)
# ('AUC:', 0.81741669707400277)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=10,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 19.164058923721313)
# ('AUC:', 0.8139062014175289)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 20.44371199607849)
# ('AUC:', 0.61310383117377776)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 21.754618883132935)
# ('AUC:', 0.63692402872175335)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 23.047322034835815)
# ('AUC:', 0.6782066687231777)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 24.163935899734497)
# ('AUC:', 0.64614203432580752)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 25.438803911209106)
# ('AUC:', 0.64664868611332027)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=20,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 26.87379503250122)
# ('AUC:', 0.66611725114320119)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=50,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 28.165930032730103)
# ('AUC:', 0.60733664458587211)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=50,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 29.49131989479065)
# ('AUC:', 0.62394078340468018)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=50,
#             max_features='sqrt', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 30.64212703704834)
# ('AUC:', 0.65624800242579373)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=50,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 31.83524799346924)
# ('AUC:', 0.61176546192687242)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=50,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=5, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 32.92641496658325)
# ('AUC:', 0.62350773601673537)
# ()
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=50,
#             max_features='log2', max_leaf_nodes=None, min_samples_leaf=1,
#             min_samples_split=10, min_weight_fraction_leaf=0.0,
#             random_state=None, splitter='best')
# ('DT', 'used:', 34.167497873306274)
# ('AUC:', 0.64992871280839648)
# ()
# SVM
# LinearSVC(C=0.001, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l1', random_state=0, tol=0.0001,
#      verbose=0)
# ('SVM', 'used:', 3.481851100921631)
# ('AUC:', 0.69341036303374159)
# ()
# LinearSVC(C=0.001, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=0, tol=0.0001,
#      verbose=0)
# ('SVM', 'used:', 4.673532962799072)
# ('AUC:', 0.64786182808431891)
# ()
# LinearSVC(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l1', random_state=0, tol=0.0001,
#      verbose=0)
# ('SVM', 'used:', 7.067860126495361)
# ('AUC:', 0.69201841874814007)
# ()
# LinearSVC(C=0.01, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=0, tol=0.0001,
#      verbose=0)
# ('SVM', 'used:', 8.282076120376587)
# ('AUC:', 0.64786181933022768)
# ()
# LinearSVC(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l1', random_state=0, tol=0.0001,
#      verbose=0)
# ('SVM', 'used:', 11.612131118774414)
# ('AUC:', 0.68991428536562283)
# ()
# LinearSVC(C=0.1, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=0, tol=0.0001,
#      verbose=0)
# ('SVM', 'used:', 12.802541017532349)
# ('AUC:', 0.64786244962480044)
# ()
# LinearSVC(C=1, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l1', random_state=0, tol=0.0001,
#      verbose=0)
# ('SVM', 'used:', 14.756679058074951)
# ('AUC:', 0.6925828125218032)
# ()
# LinearSVC(C=1, class_weight=None, dual=False, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=0, tol=0.0001,
#      verbose=0)
# ('SVM', 'used:', 15.934425115585327)
# ('AUC:', 0.64786244087070921)
# ()

# %%
print(best_model,best_params, best_auc)

# %%
print(best_model,best_params, best_auc)

# %%
print(a)
